# %% [markdown]
# # Gaussian Bayes classifier

# %%
# %matplotlib inline

from sklearn.datasets import make_blobs, make_moons, make_regression, load_iris
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 


from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Carregando Bancos de dados

# %%
dados = pd.read_csv("banco.csv")
dados = np.asarray(dados)
dados

#pd.DataFrame(dados)
# Out:
# array([['GRASS', 110.0, 189.0, ..., 18.666667999999998, 0.50813884,
#         1.9108642],
#        ['GRASS', 86.0, 187.0, ..., 19.222220999999998, 0.46332908,
#         1.9414648999999997],
#        ['GRASS', 225.0, 244.0, ..., 17.11111, 0.48014903,
#         1.9879022000000002],
#        ...,
#        ['CEMENT', 128.0, 161.0, ..., 10.888889, 0.5409177, -1.9963073],
#        ['CEMENT', 150.0, 158.0, ..., 12.222222, 0.50308645, -1.9434487],
#        ['CEMENT', 124.0, 162.0, ..., 14.555554999999998, 0.4799313,
#         -2.0293121]], dtype=object)

# %%
#A dimensão dos dados
dados.shape
# Out:
# (2100, 20)

# %%
#Carregando o Banco de dados 2
view1 = dados[:, 1:2]

#esse comando so para vizualização. Usar sempre view.
dados2 = np.asarray(view1)
pd.DataFrame(view1)
# Out:
#         0
# 0     110
# 1      86
# 2     225
# 3      47
# 4      97
# 5     157
# 6      62
# 7      27
# 8      44
# 9      17
# 10     32
# 11     55
# 12    138
# 13     90
# 14    245
# 15     58
# 16    146
# 17     19
# 18    245
# 19    228
# 20     80
# 21    184
# 22     85
# 23    162
# 24    116
# 25     44
# 26    215
# 27    200
# 28    114
# 29     30
# ...   ...
# 2070   47
# 2071  142
# 2072  249
# 2073  152
# 2074  150
# 2075  121
# 2076  150
# 2077  211
# 2078  173
# 2079   25
# 2080  215
# 2081  221
# 2082  145
# 2083   66
# 2084   46
# 2085   86
# 2086  248
# 2087  208
# 2088   43
# 2089    6
# 2090  152
# 2091   79
# 2092  166
# 2093  173
# 2094  233
# 2095   32
# 2096    8
# 2097  128
# 2098  150
# 2099  124
#
# [2100 rows x 1 columns]

# %%
#Carregando o Banco de dados3

c_view2= dados[:,0]
V_view2 = dados[:,10:20]

# %%
#esse comando so para vizualização. 
dados33 = np.asarray(c_view2)
clas=pd.DataFrame(c_view2)
#print(clas)

#esse comando so para vizualização. Usar sempre view.
dados3 = np.asarray(V_view2)
R_Banco=pd.DataFrame(V_view2)
#print(R_Banco)

#concatenando as classes com o resto do banco
view2=pd.concat([clas, R_Banco], axis=1)
#print(view2)

#esse comando so para vizualização. Usar sempre view.
dados3 = np.asarray(view2)
pd.DataFrame(view2)
# Out:
#            0          0         1         2         3         4         5  \
# 0      GRASS    12.9259   10.8889   9.22222   18.6667  -6.11111  -11.1111
# 1      GRASS    13.7407   11.6667   10.3333   19.2222  -6.22222  -10.2222
# 2      GRASS    12.2593   10.3333   9.33333   17.1111  -5.77778  -8.77778
# 3      GRASS    12.7037        11         9   18.1111  -5.11111  -11.1111
# 4      GRASS    15.5926   13.8889   11.7778   21.1111  -5.11111  -11.4444
# 5      GRASS    12.1111   10.2222   8.11111        18  -5.66667       -12
# 2073  -1.88889   2.44444  0.439153    -2.00027
# 2074  -1.77778   2.33333  0.537037    -2.00735
# 2075  -2.55556         3  0.534392    -1.90593
# 2076  -1.77778   2.33333  0.537037    -2.00735
# 2077 -0.777778  0.777778  0.555556     -2.0944
# 2078  -3.77778   5.77778  0.599735     -1.9978
# 2079        -9   21.4444  0.646298    -1.79743
# 2080  -6.33333   13.4444  0.769577    -2.14389
# 2081  -6.44444   10.7778    0.6248    -2.08798
# 2082  -8.22222   17.5556  0.747294    -2.14053
# 2083  -6.11111   12.6667  0.300624    -2.14762
# 2084  -4.77778   9.66667  0.561927 -0.00492694
# 2085  -6.22222   12.8889  0.392385     -2.0793
# 2086  -1.11111   1.11111  0.888889     -2.0944
# 2087  -7.11111   13.8889  0.771517    -2.06692
# 2088  -2.55556   2.88889  0.648677    -1.93324
# 2089 -0.222222  0.222222  0.222222     -2.0944
# 2090  -5.22222        11       0.5    -2.11557
# 2091  -1.55556   1.55556  0.288889    -1.91964
# 2092  -2.11111   1.88889         1    -2.01751
# 2093  -6.44444   11.7778  0.472975    -1.90465
# 2094  -5.88889   10.1111  0.541667    -1.99944
# 2095  -6.88889   11.8889  0.520578    -1.98283
# 2096  -5.77778        12  0.484805    -2.04495
# 2097  -6.44444   10.8889  0.540918    -1.99631
# 2098        -7   12.2222  0.503086    -1.94345
# 2099  -7.44444   14.5556  0.479931    -2.02931
#
# [2100 rows x 11 columns]

# %% [markdown]
# # Estatísticas descritivas dos dados

# %%
dados = pd.read_csv("banco.csv")
dados.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count          2100.000000          2100.000000              2100.0
# mean            124.940476           123.483333                 9.0
# std              72.858637            57.431428                 0.0
# min               1.000000            11.000000                 9.0
# 25%              62.000000            81.000000                 9.0
# 50%             121.000000           122.000000                 9.0
# 75%             188.250000           171.250000                 9.0
# max             254.000000           251.000000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2   VEDGE-MEAN     VEDGE-SD  \
# count           2100.000000           2100.000000  2100.000000  2100.000000
# mean               0.014921              0.004550     1.890820     5.708299
# std                0.041024              0.023573     2.649453    44.989359
# min                0.000000              0.000000     0.000000     0.000000
# 25%                0.000000              0.000000     0.722222     0.349603
# 50%                0.000000              0.000000     1.277776     0.833333
# 75%                0.000000              0.000000     2.222221     1.807406
# max                0.333333              0.222222    29.222221   991.718400
#
#         HEDGE-MEAN      HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  RAWBLUE-MEAN  \
# count  2100.000000  2.100000e+03     2100.000000  2100.000000   2100.000000
# mean      2.406772  7.904224e+00       37.047654    32.806667     44.205556
# std       3.469954  5.347107e+01       38.135291    34.994538     43.510119
# min       0.000000 -1.589457e-08        0.000000     0.000000      0.000000
# 25%       0.833332  4.216377e-01        7.472222     7.000000      9.666667
# 50%       1.444444  9.897442e-01       21.666666    19.666668     27.777779
# 75%       2.555556  2.251852e+00       53.277778    47.333332     65.000000
# max      44.722225  1.386329e+03      143.444440   137.111110    150.888890
#
#        RAWGREEN-MEAN   EXRED-MEAN  EXBLUE-MEAN  EXGREEN-MEAN   VALUE-MEAN  \
# count    2100.000000  2100.000000  2100.000000   2100.000000  2100.000000
# mean       34.130741   -12.722963    21.473704     -8.750741    45.162381
# std        36.303768    11.588214    19.654107     11.606996    42.900582
# min         0.000000   -49.666668   -12.444445    -33.888890     0.000000
# 25%         6.222222   -18.583333     4.305556    -17.000000    11.777778
# 50%        20.444445   -10.888889    19.666666    -11.000000    28.666666
# 75%        46.388888    -4.222222    36.111110     -3.222222    65.000000
# max       142.555560     9.888889    82.000000     24.666666   150.888890
#
#        SATURATION-MEAN     HUE-MEAN
# count      2100.000000  2100.000000
# mean          0.879188    -1.365147
# std          14.643927     1.544278
# min           0.000000    -3.044175
# 25%           0.284934    -2.188539
# 50%           0.375064    -2.052625
# 75%           0.541005    -1.565745
# max         475.000000     2.912480

# %% [markdown]
# # Validação cruzada

# %%
#Validação Cruzada para o Banco 1

X = dados[:, 1:20]
y = dados[:, 0]
skf = StratifiedKFold(n_splits=10)

for train_index, test_index in skf.split(X, y):
   print("TRAIN:", train_index, "TEST:", test_index)
   X_train, X_test = X[train_index], X[test_index]
   y_train, y_test = y[train_index], y[test_index]

###Como especificar quem é treino e teste
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-d16781eab5eb> in <module>()
#       1 #Validação Cruzada para o Banco 1
#       2
# ----> 3 X = dados[:, 1:20]
#       4 y = dados[:, 0]
#       5 skf = StratifiedKFold(n_splits=10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
#Validação Cruzada para o Banco 2

X = dados2[:, 1:10]
y = dados[:, 0]
skf = StratifiedKFold(n_splits=10)

for train_index, test_index in skf.split(X, y):
   print("TRAIN:", train_index, "TEST:", test_index)
   X_train, X_test = X[train_index], X[test_index]
   y_train, y_test = y[train_index], y[test_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-b26c5332c35e> in <module>()
#       2
#       3 X = dados2[:, 1:10]
# ----> 4 y = dados[:, 0]
#       5 skf = StratifiedKFold(n_splits=10)
#       6
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
#Validação Cruzada para o Banco 3

X = dados[:, 10:20]
y = dados[:, 0]
skf = StratifiedKFold(n_splits=10)

for train_index, test_index in skf.split(X, y):
   print("TRAIN:", train_index, "TEST:", test_index)
   X_train, X_test = X[train_index], X[test_index]
   y_train, y_test = y[train_index], y[test_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-cbe638032462> in <module>()
#       1 #Validação Cruzada para o Banco 3
#       2
# ----> 3 X = dados[:, 10:20]
#       4 y = dados[:, 0]
#       5 skf = StratifiedKFold(n_splits=10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# # Janela de parzen

# %%
#from scipy.stats import gaussian_kde

#kde = gaussian_kde(dados[1:1000,1:20].transpose(), bw_method=0.2)
#kde.evaluate(dados[1000:2000].tranpose())

# %% [markdown]
# # Classificador Bayesiano Gaussian

# %%
class BayesClassifier:
    
    mu = None
    cov = None
    n_classes = None
    
    def __init__(self):
        a = None
    
    def pred(self,x):
        prob_vect = np.zeros(self.n_classes)
        
        for i in range(self.n_classes):
            
            
            mnormal = multivariate_normal(mean=bc.mu[i], cov=bc.cov[i])
            
            # We use uniform priors
            prior = 1./self.n_classes
            
            prob_vect[i] = prior*mnormal.pdf(x)
            sumatory = 0.
            for j in range(self.n_classes):
                mnormal = multivariate_normal(mean=bc.mu[j], cov=bc.cov[j])
                sumatory += prior*mnormal.pdf(x)
            prob_vect[i] = prob_vect[i]/sumatory
        return prob_vect
        
    def fit(self, X,y):
        self.mu = []
        self.cov = []
        
        self.n_classes = np.max(y)+1
        
        for i in range(self.n_classes):
            Xc = X[y==i]
            
            mu_c = np.mean(Xc, axis=0)
            self.mu.append(mu_c)
            
            cov_c = np.zeros((X.shape[1], X.shape[1]))
            for j in range( Xc.shape[0]):
                a = Xc[j].reshape((X.shape[1],1))
                b = Xc[j].reshape((1,X.shape[1]))
                cov_ci = np.multiply(a, b)
                cov_c = cov_c+cov_ci
            cov_c = cov_c/float(X.shape[0])
            self.cov.append(cov_c)
        self.mu = np.asarray(self.mu)
        self.cov = np.asarray(self.cov)

# %%
#Carregando o Banco de dados 2
view1 = dados[:, 0:10]
print(view1)
# Out:
# [['GRASS' 110.0 189.0 ... 0.66666675 1.2222223 1.1863422]
#  ['GRASS' 86.0 187.0 ... 0.7200825 1.4444445 0.750309]
#  ['GRASS' 225.0 244.0 ... 2.1951127 2.9999998 1.5202343]
#  ...
#  ['CEMENT' 128.0 161.0 ... 0.25185192 0.77777785 0.16296278]
#  ['CEMENT' 150.0 158.0 ... 1.6333338 1.388889 0.41851807]
#  ['CEMENT' 124.0 162.0 ... 1.1296295 2.0 0.8888891]]

# %%
bc = BayesClassifier()

print (bc)

view1 = dados[:, 1:2]

bc.fit(X,Y)
# Out:
# <__main__.BayesClassifier object at 0x0000009F60AFC400>

# %%
hit = 0.

for i in range(X_test.shape[0]):
    ypred = bc.pred(X_test[i])
    if np.argmax(ypred) == y_test[i]:
        hit += 1

print ("Not so naive Gaussian bayes score: "+str(hit/X_test.shape[0]))

# %% [markdown]
# # Classificador da soma

# %% [markdown]
# # TESTES UTILIZADOS

# %% [markdown]
# # Estimativa pontual e um intervalo de confiança para cada classificador

# %% [markdown]
# # Teste de Friedman

# %% [markdown]
# # Teste de Nemenyi

# %%
#intervalo de confiança para taxa de acerto?????


#salva as saidas dos dados

#np .  savetxt ( './training_set.csv' , training_data , delimiter = ',' )
#np .  savetxt ( './test_set.csv' , test_data , delimiter = ',' )

# %% [markdown]
# #janela de Parzen

# %%
from sklearn.neighbors.kde import KernelDensity
import numpy as np
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
print(X)
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(X)
kde.score_samples(X)
# Out:
# [[-1 -1]
#  [-2 -1]
#  [-3 -2]
#  [ 1  1]
#  [ 2  1]
#  [ 3  2]]
# array([-0.41075698, -0.41075698, -0.41076071, -0.41075698, -0.41075698,
#        -0.41076071])

# %%
from scipy import stats
import scipy as sp
import numpy as np
 
s = np.array([1,2,3,4,4,4,5,5,5,5,4,4,4,6,7,8])

# %%
from scipy import stats
import scipy as sp
import numpy as np
 
s = np.array([1,2,3,4,4,4,5,5,5,5,4,4,4,6,7,8])
s.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-162b1ffb61e7> in <module>()
#       4
#       5 s = np.array([1,2,3,4,4,4,5,5,5,5,4,4,4,6,7,8])
# ----> 6 s.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
s = np.array([1,2,3,4,4,4,5,5,5,5,4,4,4,6,7,8])
n, min_max, mean, var, skew, kurt = stats.describe(s)
